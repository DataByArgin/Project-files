# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)


# read the data

df = pd.read_csv(r'/Users/Argin_Mac/movies.csv')

# %%
# Let's take a look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#      released  score      votes         director                   writer  \
# 0  1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1  1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3  1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime
# 0    146.0
# 1    104.0
# 2    124.0
# 3     88.0
# 4     98.0

# %%
# Check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
# Data Types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data types of columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# create correct year column

df['Year_Correct'] = df['released'].astype('str').str[:4]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7661                                    More to Life    NaN      Drama  2020
# 7662                                     Dream Round    NaN     Comedy  2020
# 7663                                   Saving Mbango    NaN      Drama  2020
# 7664                                    It's Just Us    NaN      Drama  2020
# 7665                                       Tee em el    NaN     Horror  2020
#
#         released  score      votes         director                   writer  \
# 0     1980-06-13    8.4   927000.0  Stanley Kubrick             Stephen King
# 1     1980-07-02    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2     1980-06-20    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3     1980-07-02    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4     1980-07-25    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
# ...          ...    ...        ...              ...                      ...
# 7661  2020-10-23    3.1       18.0    Joseph Ebanks            Joseph Ebanks
# 7662  2020-02-07    4.7       36.0     Dusty Dukatz              Lisa Huston
# 7663  2020-04-27    5.7       29.0     Nkanya Nkwai             Lynno Lovert
# 7664  2020-10-01    NaN        NaN    James Randall            James Randall
# 7665  2020-08-19    5.7        7.0     Pereko Mosia             Pereko Mosia
#
#                   star         country    budget      gross  \
# 0       Jack Nicholson  United Kingdom  19000000   46998772
# 1       Brooke Shields   United States   4500000   58853106
# 2          Mark Hamill   United States  18000000  538375067
# 3          Robert Hays   United States   3500000   83453539
# 4          Chevy Chase   United States   6000000   39846344
# ...                ...             ...       ...        ...
# 7661      Shannon Bond   United States      7000          0
# 7662  Michael Saquella   United States         0          0
# 7663      Onyama Laura   United States     58750          0
# 7664     Christina Roz   United States     15000          0
# 7665  Siyabonga Mabaso    South Africa         0          0
#
#                         company  runtime Year_Correct
# 0                  Warner Bros.    146.0         1980
# 1             Columbia Pictures    104.0         1980
# 2                     Lucasfilm    124.0         1980
# 3            Paramount Pictures     88.0         1980
# 4                Orion Pictures     98.0         1980
# ...                         ...      ...          ...
# 7661                        NaN     90.0         2020
# 7662  Cactus Blue Entertainment     90.0         2020
# 7663           Embi Productions      NaN         2020
# 7664                        NaN    120.0         2020
# 7665                PK 65 Films    102.0         2020
#
# [7666 rows x 16 columns]

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 5445                                      Avatar      PG-13     Action  2009
# 7443                           Avengers: Endgame      PG-13     Action  2019
# 3045                                     Titanic      PG-13      Drama  1997
# 6661  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7242                      Avengers: Infinity War      PG-13     Action  2018
# ...                                          ...        ...        ...   ...
# 327                                Boardinghouse          R     Comedy  1982
# 326                                   Love Child          R      Crime  1982
# 324                             The Wizard of Oz  Not Rated  Animation  1982
# 1199                             Walk Like a Man         PG     Comedy  1987
# 7665                                   Tee em el        NaN     Horror  2020
#
#         released  score      votes           director              writer  \
# 5445  2009-12-18    7.8  1100000.0      James Cameron       James Cameron
# 7443  2019-04-26    8.4   903000.0      Anthony Russo  Christopher Markus
# 3045  1997-12-19    7.8  1100000.0      James Cameron       James Cameron
# 6661  2015-12-18    7.8   876000.0        J.J. Abrams     Lawrence Kasdan
# 7242  2018-04-27    8.4   897000.0      Anthony Russo  Christopher Markus
# ...          ...    ...        ...                ...                 ...
# 327   1983-10-21    3.8      651.0    John Wintergate     John Wintergate
# 326   1982-10-15    5.7      253.0       Larry Peerce         Anne Gerard
# 324   1982-10-06    6.8      352.0  Fumihiko Takayama    Yoshimitsu Banno
# 1199  1987-04-17    4.8     1400.0       Melvin Frank        Robert Klane
# 7665  2020-08-19    5.7        7.0       Pereko Mosia        Pereko Mosia
#
#                    star        country     budget       gross  \
# 5445    Sam Worthington  United States  237000000  2847246203
# 7443  Robert Downey Jr.  United States  356000000  2797501328
# 3045  Leonardo DiCaprio  United States  200000000  2201647264
# 6661       Daisy Ridley  United States  245000000  2069521700
# 7242  Robert Downey Jr.  United States  321000000  2048359754
# ...                 ...            ...        ...         ...
# 327     John Wintergate  United States      10000           0
# 326         Amy Madigan  United States          0           0
# 324        Aileen Quinn  United States          0           0
# 1199  Christopher Lloyd  United States          0           0
# 7665   Siyabonga Mabaso   South Africa          0           0
#
#                         company  runtime Year_Correct
# 5445      Twentieth Century Fox    162.0         2009
# 7443             Marvel Studios    181.0         2019
# 3045      Twentieth Century Fox    194.0         1997
# 6661                  Lucasfilm    138.0         2015
# 7242             Marvel Studios    149.0         2018
# ...                         ...      ...          ...
# 327                    Blustarr     98.0         1983
# 326            The Ladd Company     96.0         1982
# 324            Alan Enterprises     78.0         1982
# 1199  Metro-Goldwyn-Mayer (MGM)     86.0         1987
# 7665                PK 65 Films    102.0         2020
#
# [7666 rows x 16 columns]

# %%
# scatter plot with Budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlations

df.corr(method='pearson') # pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.098171  0.222952  0.309407  0.262038  0.120811
# score    0.098171  1.000000  0.409221  0.055549  0.186323  0.399451
# votes    0.222952  0.409221  1.000000  0.486901  0.632860  0.309212
# budget   0.309407  0.055549  0.486901  1.000000  0.750141  0.269510
# gross    0.262038  0.186323  0.632860  0.750141  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# correlation heatmap

correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Numeric Features")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value
df_factorize = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

# %%
# updated correlation heatmap

correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
strong_pairs = sorted_pairs[(abs(sorted_pairs) > 0.5) & (abs(sorted_pairs) != 1)]

print(strong_pairs)
# Out:
# star          company         0.527587
# company       star            0.527587
# writer        company         0.547258
# company       writer          0.547258
#               director        0.552612
# director      company         0.552612
# gross         company         0.587871
# company       gross           0.587871
#               name            0.592092
# name          company         0.592092
# company       year            0.601992
# year          company         0.601992
# company       released        0.604148
# released      company         0.604148
# star          Year_Correct    0.640012
# Year_Correct  star            0.640012
# director      Year_Correct    0.642860
# Year_Correct  director        0.642860
# star          writer          0.676389
# writer        star            0.676389
# star          director        0.682539
# director      star            0.682539
# Year_Correct  writer          0.708629
# writer        Year_Correct    0.708629
# star          name            0.731467
# name          star            0.731467
# star          gross           0.736775
# gross         star            0.736775
# director      name            0.745971
# name          director        0.745971
# writer        director        0.748852
# director      writer          0.748852
# gross         director        0.751685
# director      gross           0.751685
# released      star            0.754949
# star          released        0.754949
#               year            0.756308
# year          star            0.756308
# director      released        0.770035
# released      director        0.770035
# year          director        0.770572
# director      year            0.770572
# name          writer          0.805846
# writer        name            0.805846
#               gross           0.806830
# gross         writer          0.806830
# name          Year_Correct    0.821571
# Year_Correct  name            0.821571
# writer        released        0.822226
# released      writer          0.822226
# writer        year            0.825393
# year          writer          0.825393
# Year_Correct  gross           0.831960
# gross         Year_Correct    0.831960
# released      Year_Correct    0.848157
# Year_Correct  released        0.848157
# year          Year_Correct    0.850379
# Year_Correct  year            0.850379
# name          gross           0.948347
# gross         name            0.948347
# released      name            0.961055
# name          released        0.961055
# year          name            0.965751
# name          year            0.965751
# gross         released        0.977068
# released      gross           0.977068
# year          gross           0.981895
# gross         year            0.981895
# released      year            0.994858
# year          released        0.994858
# dtype: float64
